# %% [markdown]
# # React - Guide pour démarrer

# %% [markdown]
# ## Qu'est-ce que React ?

# %% [markdown]
# React est une **bibliothèque JavaScript** développée par Facebook (maintenant Meta) qui permet de créer des interfaces utilisateur (UI) modernes et interactives. Elle utilise une approche basée sur les **composants réutilisables**.
#
# React utilise un DOM virtuel pour optimiser les mises à jour de l'interface. Les changements sont d'abord appliqués au DOM virtuel, puis React met à jour uniquement les parties modifiées du DOM réel.

# %% [markdown]
# ### Avantages de React

# %% [markdown]
# - ✅ **Modularité** : Les composants réutilisables facilitent la maintenance du code
# - ✅ **Performance** : Le Virtual DOM optimise les mises à jour
# - ✅ **Communauté active** : Large écosystème d'outils et de bibliothèques
# - ✅ **Flexibilité** : Peut être utilisé pour des applications web simples ou complexes
# - ✅ **Documentation riche** : Beaucoup de ressources disponibles en ligne

# %% [markdown]
# ### Cas d'usage

# %% [markdown]
# React est idéal pour :
# - 🖥️ **Applications web modernes** (Single Page Applications)
# - 📱 **Applications mobiles** (avec React Native)
# - 🎨 **Interfaces dynamiques et interactives**
# - 📊 **Tableaux de bord et applications de données**
# - 🛒 **Plateforme e-commerce**

# %% [markdown]
# ## Comment commencer ?

# %% [markdown]
# ### Installation avec Create React App

# %%
npx create-react-app mon-app
cd mon-app
npm start

# %% [markdown]
# ### Installation avec Vite (plus rapide)

# %%
npm create vite@latest mon-app -- --template react
cd mon-app
npm install
npm run dev

# %% [markdown]
# ## Caractéristiques principales

# %% [markdown]
# ### JSX - JavaScript XML
# JSX est une syntaxe qui permet d'écrire du HTML directement en JavaScript. Elle est transpilée en appels JavaScript normaux.

# %%
const element = <h1>Bonjour React!</h1>;

# %% [markdown]
# ### Approche basée sur les composants
# React encourage le développement par composants, des blocs de code réutilisables qui gèrent leur propre état et affichage.

# %%
function Bouton() {
  return <button>Cliquez-moi</button>;
}

# %% [markdown]
# ### Gestion de l'état (State)
# Chaque composant peut avoir son propre état interne qui, lorsqu'il change, provoque une re-affichage automatique du composant.

# %%
import { useState } from 'react';

function Compteur() {
  const [count, setCount] = useState(0);
  
  return (
    <div>
      <p>Compte: {count}</p>
      <button onClick={() => setCount(count + 1)}>Incrémenter</button>
    </div>
  );
}

# %% [markdown]
# ### Props (Propriétés)
# Les props permettent de passer des données d'un composant parent à un composant enfant.

# %%
function Salutation({ nom }) {
  return <p>Bonjour {nom}</p>;
}

# %%
// Utilisation
<Salutation nom="Alice" />

# %% [markdown]
# ### Hooks (Crochets)
# Les hooks sont des fonctions spéciales qui permettent d'ajouter des fonctionnalités à des composants fonctionnels.
#
# - **useState** : Gère l'état local
# - **useEffect** : Gère les effets secondaires (requêtes API, timers, etc.)
# - **useContext** : Accède au contexte global

# %%
import { useState, useEffect } from 'react';

function MonComposant() {
  const [data, setData] = useState(null);
  
  useEffect(() => {
    fetch('/api/data')
      .then(res => res.json())
      .then(data => setData(data));
  }, []);
  
  return <div>{data}</div>;
}

# %% [markdown]
# ## Conclusion

# %% [markdown]
# React est devenu l'une des bibliothèques JavaScript les plus populaires pour développer des interfaces web modernes. Son approche basée sur les composants et sa performance en font un choix excellent pour les projets de toutes tailles.

# %% [markdown]
# ### Ressources utiles

# %% [markdown]
# - [Documentation officielle React](https://react.dev)
# - [Tutoriels interactifs](https://react.dev/learn)
# - [React Router](https://reactrouter.com) - Pour la navigation
# - [Redux](https://redux.js.org) - Pour la gestion d'état globale
# - [Next.js](https://nextjs.org) - Framework React avec rendu serveur
